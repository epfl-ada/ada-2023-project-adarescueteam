# %%
import pandas as pd

columns_name=['beer_name', 'beer_id','brewery_name','brewery_id',
              'style','abv','date','user_name','user_id','appearance',
              'aroma','palate','taste','overall','rating','text']

df=pd.DataFrame(columns=columns_name)
with open('glutenfree_beers.txt', 'r') as file:
    for i,line in enumerate(file):
        j=i % 17
        if (j!=0):
            df.at[int(i/17),columns_name[j-1]]=line.strip().split(':',1)[1]

# %%
df
# Out:
#                                     beer_name  beer_id  \
# 0                 Kowloon Bay Gluten Free IPA   436710
# 1                 Glutenberg 1er Anniversaire   182791
# 2                 Glutenberg 1er Anniversaire   182791
# 3                 Glutenberg 1er Anniversaire   182791
# 4                 Glutenberg 1er Anniversaire   182791
# ...                                       ...      ...
# 3765   Grain dOrge Glutenfri Ekologisk Lager   477827
# 3766   Grain dOrge Glutenfri Ekologisk Lager   477827
# 3767   Grain dOrge Glutenfri Ekologisk Lager   477827
# 3768   Grain dOrge Glutenfri Ekologisk Lager   477827
# 3769   Grain dOrge Glutenfri Ekologisk Lager   477827
#
#                              brewery_name brewery_id                  style  \
# 0                     Kowloon Bay Brewery      25260   India Pale Ale (IPA)
# 1              Glutenberg Brewing Company      13241        Specialty Grain
# ...

# %%
df['text']
# Out:
# 0        Drank at Home: Eat To Live cafe. Floral hop n...
# 1        BiÃ¨re cuivrÃ©e. Nez houblon-caramel. En bouc...
# 2        Une belle brune qui dÃ©gage immÃ©diatement de...
# 3        Bouteille 750ml. De couleur ambrÃ©e foncÃ©e e...
# 4        pours clear medium dark golden with a decent ...
#                               ...
# 3765     25 cl bottle from Copp Avenyn, GÃ¶teborg. Sam...
# 3766     250ml bottle. Clear pale golden, medium size ...
# 3767     250ml green bottle poured into a lager glass....
# 3768     Bottle. Pours clear amber, no head. Aroma mal...
# 3769     Bottle, wedding gift from vjohans.Pours amber...
# Name: text, Length: 3770, dtype: object

# %%
import datetime
dates=[ int(date) for date in df['date']]
readable_date = [datetime.datetime.fromtimestamp(timestamp) for timestamp in dates]
df['year']=[ time.year for time in readable_date]
df['month']=[ time.month for time in readable_date]
df['year']
# Out:
# 0       2016
# 1       2013
# 2       2013
# 3       2013
# 4       2013
#         ...
# 3765    2017
# 3766    2017
# 3767    2017
# 3768    2017
# 3769    2017
# Name: year, Length: 3770, dtype: int64

# %%
csv_file_path = 'glutenfree.csv'  
df.to_csv(csv_file_path, index=False)

# %%
columns_name = ['beer_name', 'beer_id', 'brewery_name', 'brewery_id',
                'style', 'abv', 'date', 'user_name', 'user_id', 'appearance',
                'aroma', 'palate', 'taste', 'overall', 'rating', 'text']

# Create an empty DataFrame with the specified column names
df = pd.DataFrame(columns=columns_name)

with open('micro_breweries.txt', 'r') as file:
    data = {}
    for i, line in enumerate(file):
        if i % 17 == 0:
            # This is the last line of a group, so add the data to the DataFrame
            #df = pd.concat([df, pd.DataFrame(data)], ignore_index=True)
            df = df._append(data, ignore_index=True)
            data = {}
        else:
            #print(line)
            # Split the line at the first ':' and assign the values to the corresponding column
            key, value = line.strip().split(':', 1)
            data[columns_name[i % 17 - 1]] = value

# %%
df
# Out:
#                        beer_name  beer_id  \
# 0                            NaN      NaN
# 1       AdstraGold 188 Nutty IPA   224983
# 2       AdstraGold 188 Nutty IPA   224983
# 3       AdstraGold 188 Nutty IPA   224983
# 4       AdstraGold 188 Nutty IPA   224983
# ...                          ...      ...
# 32539      Chiangmai Weizen Bock    45850
# 32540      Chiangmai Weizen Bock    45850
# 32541        Brew Pavilion Lager    16784
# 32542        Brew Pavilion Lager    16784
# 32543       Brew Pavilion Wiezen    16783
#
#                                        brewery_name brewery_id  \
# 0                                               NaN        NaN
# 1              AdstraGold Microbrewery & Bistro Bar      15008
# 2              AdstraGold Microbrewery & Bistro Bar      15008
# 3              AdstraGold Microbrewery & Bistro Bar      15008
# 4              AdstraGold Microbrewery & Bistro Bar      15008
# ...                                             ...        ...
# ...

# %%
df['date']
# Out:
# 0                NaN
# 1         1476698400
# 2         1476698400
# 3         1395572400
# 4         1387796400
#             ...
# 32539     1325242800
# 32540     1113127200
# 32541     1072090800
# 32542     1033812000
# 32543     1072090800
# Name: date, Length: 32544, dtype: object

# %%
(pd.isna('NaN'))
# Out:
# False

# %%
dates=[int(date) if not pd.isna(date) else None for date in df['date']]
readable_dates = []
for timestamp in dates:

    if pd.isna(timestamp):
        readable_dates.append(None)
    else:
        readable_dates.append(datetime.datetime.fromtimestamp(timestamp))

df['year'] = [time.year if not pd.isna(time) else 'NaN' for time in readable_dates]
df['month'] = [time.month if not pd.isna(time) else 'NaN' for time in readable_dates]

# %%
csv_file_path = 'micro-breweries.csv'  
df.to_csv(csv_file_path, index=False)
